# %% [markdown]
# <a href="https://colab.research.google.com/github/hmyrcmn/schools/blob/main/Untitled37.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout

# !git clone https://github.com/hmyrcmn/KUL.git

# Veri yükleme
true_folder = '/content/KUL/trueValues5'
X_data = []
Y_labels = []

for filename in os.listdir(true_folder):
    data = np.genfromtxt(os.path.join(true_folder, filename), delimiter=',')
    # X_data.append(data)
    X_data.append(data[:, 1:])  # Sadece virgül sonrasındaki değerleri ekledim

    Y_labels.append(1)

false_folder = '/content/KUL/falseValues6'
for filename in os.listdir(false_folder):
    data = np.genfromtxt(os.path.join(false_folder, filename), delimiter=',')
    # X_data.append(data)
    X_data.append(data[:, 1:])  # Sadece virgül sonrasındaki değerleri ekledim

    Y_labels.append(0)

X_data = np.array(X_data)
Y_labels = np.array(Y_labels)
print("x_data shape: ",X_data.shape)
X_data

# %%
# Verileri düzenleme ve normalleştirme
num_samples = len(X_data)
sequence_length = X_data.shape[1]
num_features = X_data.shape[2]

X_data_normalized = X_data.reshape(num_samples, sequence_length * num_features)

# Eğitim ve test setlerine bölme

X_train, X_test, y_train, y_test = train_test_split(X_data_normalized, Y_labels, test_size=0.2, random_state=42)

print("X_train.shape:",X_train.shape)
X_train
# Out:
# X_train.shape: (1600, 100)
# array([[239.58333333, 240.5232024 , 241.16042515, ..., 239.09361956,
#         239.59022226, 238.23051948],
#        [239.58333333, 239.62462574, 241.16042515, ..., 239.09361956,
#         238.88162163, 238.23051948],
#        [239.58333333, 240.5232024 , 241.16042515, ..., 239.09361956,
#         238.88162163, 238.23051948],
#        ...,
#        [239.58333333, 240.5232024 , 241.16042515, ..., 239.09361956,
#         238.88162163, 238.04528351],
#        [194.46204202, 194.31355858, 194.1771709 , ..., 198.52538995,
#         198.8606285 , 199.21338824],
#        [194.46204202, 200.23677266, 194.1771709 , ..., 198.52538995,
#         198.8606285 , 193.38326129]])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the paths to your text files
true1 = '/content/KUL/trueValues5/smooth2001_0.txt'
false1 = '/content/KUL/falseValues6/smooth2001_0.txt'

# Load data from the first text file
data1 = np.genfromtxt(true1, delimiter=',')
y_values1 = data1[:, 1]

# Load data from the second text file
data2 = np.genfromtxt(false1, delimiter=',')
y_values2 = data2[:, 1]

# Plot the data from both files on the same graph
plt.plot(y_values1, label='true1')
plt.plot(y_values2, label='false1')

# Add labels and title
plt.xlabel('Data Point Index')
plt.ylabel('Y Values')
plt.title('Data from Two Text Files')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ccf4a941a3d9> in <cell line: 13>()
#      11
#      12 # Load data from the second text file
# ---> 13 data2 = np.genfromtxt(false1, delimiter=',')
#      14 y_values2 = data2[:, 1]
#      15
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1957         fname = os_fspath(fname)
#    1958     if isinstance(fname, str):
# -> 1959         fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1960         fid_ctx = contextlib.closing(fid)
#    1961     else:
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     191
#     192     ds = DataSource(destpath)
# --> 193     return ds.open(path, mode, encoding=encoding, newline=newline)
#     194
#     195
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     531                                       encoding=encoding, newline=newline)
#     532         else:
# --> 533             raise FileNotFoundError(f"{path} not found.")
#     534
#     535
#
# FileNotFoundError: /content/KUL/falseValues6/smooth2001_0.txt not found.

# %%
import os
import matplotlib.pyplot as plt

# Folder path where the text files are located
folder_path = '/content/KUL/falseValues6'

# Get the list of all .txt files in the folder
file_names = [filename for filename in os.listdir(folder_path) if filename.endswith('.txt')]

# Lists to store x and y values from all files
all_x_values = []
all_y_values = []

# Process each file
for file_name in file_names:
    x_values = []  # To store x values for each file
    y_values = []  # To store y values for each file

    file_path = os.path.join(folder_path, file_name)

    with open(file_path, 'r') as f:
        for line in f.readlines():
            x_values.append(float(line.split(',')[0]))
            y_values.append(float(line.split(',')[1]))

    # Append x_values and y_values to the lists
    all_x_values.append(x_values)
    all_y_values.append(y_values)

    # Do something with x_values and y_values, for example, print or process further
    #print(f"File: {file_name}, X Values: {x_values}, Y Values: {y_values}")

# Plot the data
plt.figure(figsize=(10, 6))
for x_values, y_values in zip(all_x_values, all_y_values):
    plt.plot(x_values, y_values, label=f'Data from {file_name}')

plt.title('false values')
plt.xlabel('X Values')
plt.xlim(0, 1000)
plt.ylim(200, 250)
plt.ylabel('Y Values')
plt.show()

# %%
import os
import matplotlib.pyplot as plt

# Folder path where the text files are located
folder_path = '/content/KUL/trueValues5'

# Get the list of all .txt files in the folder
file_names = [filename for filename in os.listdir(folder_path) if filename.endswith('.txt')]

# Lists to store x and y values from all files
all_x_values = []
all_y_values = []

# Process each file
for file_name in file_names:
    x_values = []  # To store x values for each file
    y_values = []  # To store y values for each file

    file_path = os.path.join(folder_path, file_name)

    with open(file_path, 'r') as f:
        for line in f.readlines():
            x_values.append(float(line.split(',')[0]))
            y_values.append(float(line.split(',')[1]))

    # Append x_values and y_values to the lists
    all_x_values.append(x_values)
    all_y_values.append(y_values)

    # Do something with x_values and y_values, for example, print or process further
    #print(f"File: {file_name}, X Values: {x_values}, Y Values: {y_values}")

# Plot the data
plt.figure(figsize=(10, 6))
for x_values, y_values in zip(all_x_values, all_y_values):
    plt.plot(x_values, y_values, label=f'Data from {file_name}')

plt.title('true values')
plt.xlabel('X Values')
plt.xlim(0, 1000)
plt.ylim(200, 250)
plt.ylabel('Y Values')
plt.show()

# %%
import matplotlib.pyplot as plt

# Select a sample to visualize
sample_index = 1599
sample = X_train[sample_index]

# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(sample)

plt.xlabel('Feature Index')
plt.ylabel('Feature Value')
plt.title('Line Plot of X_train Sample')

plt.show()

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split

# Eğitim ve test setlerine bölme
X_train, X_test, y_train, y_test = train_test_split(X_data_normalized, Y_labels, test_size=0.2, random_state=42)

# Sinir ağı modelini oluşturma
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(sequence_length * num_features,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='sigmoid'))
model.add(Dense(2, activation='sigmoid'))  # sigmoid aktivasyonu ve 1 nöron

# Modeli derleme
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Modeli eğitme
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.2)

# Modelin performansını değerlendirme
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')

# Model özetini yazdırma
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c044b2bee2ce> in <cell line: 6>()
#       4
#       5 # Eğitim ve test setlerine bölme
# ----> 6 X_train, X_test, y_train, y_test = train_test_split(X_data, Y_labels, test_size=0.2, random_state=42)
#       7
#       8 # Sinir ağı modelini oluşturma
#
# NameError: name 'X_data' is not defined

# %%
from keras import layers

model = Sequential()
model.add(Dense(1000, activation='relu', input_shape=(sequence_length * num_features,)))
model.add(layers.BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(500, activation='relu', input_shape=(sequence_length * num_features,)))
model.add(layers.BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(2, activation='relu'))
# Modeli derleme
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Modeli eğitme
model.fit(X_train, y_train, epochs=10, batch_size=16, validation_split=0.2)

# Modelin performansını değerlendirme
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')

# Model özetini yazdırma
model.summary()
# Out:
# Epoch 1/10
# 80/80 [==============================] - 10s 20ms/step - loss: 2.0659 - accuracy: 0.7820 - val_loss: 8.2918 - val_accuracy: 0.5437
# Epoch 2/10
# 80/80 [==============================] - 1s 14ms/step - loss: 0.3196 - accuracy: 0.7656 - val_loss: 8.2918 - val_accuracy: 0.5437
# Epoch 3/10
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1074 - accuracy: 0.7391 - val_loss: 0.0000e+00 - val_accuracy: 0.5437
# Epoch 4/10
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0846 - accuracy: 0.6609 - val_loss: 0.0000e+00 - val_accuracy: 0.5437
# Epoch 5/10
# 80/80 [==============================] - 1s 14ms/step - loss: 0.0633 - accuracy: 0.6703 - val_loss: 0.0000e+00 - val_accuracy: 0.5437
# Epoch 6/10
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0536 - accuracy: 0.6812 - val_loss: 0.0000e+00 - val_accuracy: 0.5437
# Epoch 7/10
# 80/80 [==============================] - 2s 22ms/step - loss: 0.0455 - accuracy: 0.6609 - val_loss: 0.0000e+00 - val_accuracy: 0.5437
# Epoch 8/10
# 80/80 [==============================] - 2s 21ms/step - loss: 0.0469 - accuracy: 0.6789 - val_loss: 0.0000e+00 - val_accuracy: 0.5437
# Epoch 9/10
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0200 - accuracy: 0.6938 - val_loss: 0.0000e+00 - val_accuracy: 0.5437
# Epoch 10/10
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0202 - accuracy: 0.6883 - val_loss: 0.0000e+00 - val_accuracy: 0.5437
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.5025
# Test accuracy: 0.5024999976158142
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_33 (Dense)            (None, 1000)              101000
#
#  batch_normalization_8 (Bat  (None, 1000)              4000
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 1000)              0
#
#  dense_34 (Dense)            (None, 500)               500500
#
#  batch_normalization_9 (Bat  (None, 500)               2000
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 500)               0
#
#  dense_35 (Dense)            (None, 256)               128256
#
#  batch_normalization_10 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_36 (Dense)            (None, 128)               32896
#
#  batch_normalization_11 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_37 (Dense)            (None, 64)                8256
#
#  dense_38 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 778574 (2.97 MB)
# Trainable params: 774806 (2.96 MB)
# Non-trainable params: 3768 (14.72 KB)
# _________________________________________________________________

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout

# !git clone https://github.com/hmyrcmn/KUL.git

# Veri yükleme
true_folder = '/content/KUL/error'
X_data = []
Y_labels = []

for filename in os.listdir(true_folder):
    data = np.genfromtxt(os.path.join(true_folder, filename), delimiter=',')
    # X_data.append(data)
    X_data.append(data[:, 1:])  # Sadece virgül sonrasındaki değerleri ekledim

    Y_labels.append(1)

false_folder = '/content/error2'
for filename in os.listdir(false_folder):

    data = np.genfromtxt(os.path.join(false_folder, filename), delimiter=',')
    # X_data.append(data)
    X_data.append(data[:, 1:])  # Sadece virgül sonrasındaki değerleri ekledim

    Y_labels.append(0)

X_data = np.array(X_data)
Y_labels = np.array(Y_labels)
print("x_data shape: ",X_data.shape)
X_data[0]

# Verileri düzenleme ve normalleştirme
num_samples = len(X_data)
sequence_length = X_data.shape[1]
num_features = X_data.shape[2]

X_data_normalized2 = X_data.reshape(num_samples, sequence_length * num_features)
print("y:",Y_labels.shape)
Y_labels
# Out:
# fatal: destination path 'KUL' already exists and is not an empty directory.
# x_data shape:  (6, 100, 1)
# y: (6,)
# array([1, 1, 0, 0, 0, 0])

# %%
# Model ile tahmin yapma
predictions = model.predict(X_data_normalized2)

# Tahmin sonuçlarını eşik değere göre ikili sınıflara dönüştürme
binary_predictions = (predictions > 0.5).astype(int)

# Her bir örnek için tahmin edilen sınıfı ve olasılığı yazdırma
for i in range(len(binary_predictions)):
    predicted_class = binary_predictions[i][0]  # Sadece ilk sınıfın tahminini al
    probability = predictions[i][predicted_class]  # Tahmin edilen sınıfa ait olasılığı al
    print(f"Sample {i + 1}: Predicted Class: {predicted_class}, Probability: {probability:.4f}")
# Out:
# 1/1 [==============================] - 0s 311ms/step
# Sample 1: Predicted Class: 1, Probability: 5.2098
# Sample 2: Predicted Class: 1, Probability: 5.1758
# Sample 3: Predicted Class: 1, Probability: 5.1758
# Sample 4: Predicted Class: 1, Probability: 2.0387
# Sample 5: Predicted Class: 0, Probability: 0.0000
# Sample 6: Predicted Class: 0, Probability: 0.0000

# %%
from keras import layers

model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(sequence_length * num_features,)))
model.add(layers.BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(layers.BatchNormalization())
model.add(Dense(1, activation='sigmoid'))

# Modeli derleme
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Modeli eğitme
model.fit(X_train, y_train, epochs=10, batch_size=16, validation_split=0.2)

# Modelin performansını değerlendirme
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')

# Model özetini yazdırma
model.summary()
# Out:
# Epoch 1/10
# 80/80 [==============================] - 3s 8ms/step - loss: 0.3083 - accuracy: 0.8773 - val_loss: 619.6729 - val_accuracy: 0.5437
# Epoch 2/10
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2970 - accuracy: 0.8875 - val_loss: 727.6432 - val_accuracy: 0.5437
# Epoch 3/10
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2876 - accuracy: 0.8914 - val_loss: 383.3552 - val_accuracy: 0.5437
# Epoch 4/10
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2672 - accuracy: 0.9094 - val_loss: 544.8839 - val_accuracy: 0.5437
# Epoch 5/10
# 80/80 [==============================] - 1s 8ms/step - loss: 0.2673 - accuracy: 0.8992 - val_loss: 441.2300 - val_accuracy: 0.5437
# Epoch 6/10
# 80/80 [==============================] - 1s 8ms/step - loss: 0.2640 - accuracy: 0.8984 - val_loss: 598.5530 - val_accuracy: 0.5437
# Epoch 7/10
# 80/80 [==============================] - 1s 7ms/step - loss: 0.2657 - accuracy: 0.8984 - val_loss: 392.7278 - val_accuracy: 0.5437
# Epoch 8/10
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2550 - accuracy: 0.9102 - val_loss: 302.0189 - val_accuracy: 0.5437
# Epoch 9/10
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2260 - accuracy: 0.9219 - val_loss: 472.9957 - val_accuracy: 0.5437
# Epoch 10/10
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2605 - accuracy: 0.9055 - val_loss: 385.5652 - val_accuracy: 0.5437
# 13/13 [==============================] - 0s 3ms/step - loss: 420.3994 - accuracy: 0.5025
# Test accuracy: 0.5024999976158142
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 256)               51456
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_16 (Dense)            (None, 128)               32896
#
#  batch_normalization_4 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_17 (Dense)            (None, 64)                8256
#
#  batch_normalization_5 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_18 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 94465 (369.00 KB)
# Trainable params: 93569 (365.50 KB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
# Sinir ağı modelini oluşturma
model = Sequential()
model.add(Dense(5000, activation='relu', input_shape=(sequence_length * num_features,)))

# model.add(Dense(256, activation='relu' ))
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu'))

model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Modeli derleme
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Modeli eğitme
model.fit(X_train, y_train, epochs=10, batch_size=16, validation_split=0.2)

# Modelin performansını değerlendirme
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')

# Model özetini yazdırma
model.summary()

# Model ile tahmin yapma
predictions = model.predict(X_test)

# Tahmin ve gerçek sınıfları içeren bir confusion matrix oluştur
conf_matrix = confusion_matrix(y_test, (predictions > 0.5).astype(int))

# Confusion matrix'i seaborn kütüphanesi ile görselleştirme
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Gerçek 0', 'Gerçek 1'], yticklabels=['Tahmin 0', 'Tahmin 1'])
plt.xlabel('Gerçek Sınıf')
plt.ylabel('Tahmin Edilen Sınıf')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Epoch 1/10
# 80/80 [==============================] - 5s 29ms/step - loss: 62.8497 - accuracy: 0.4945 - val_loss: 0.6959 - val_accuracy: 0.4563
# Epoch 2/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.9844 - accuracy: 0.5023 - val_loss: 0.6947 - val_accuracy: 0.4563
# Epoch 3/10
# 80/80 [==============================] - 2s 25ms/step - loss: 0.7224 - accuracy: 0.5055 - val_loss: 0.6949 - val_accuracy: 0.4563
# Epoch 4/10
# 80/80 [==============================] - 2s 23ms/step - loss: 0.7127 - accuracy: 0.5109 - val_loss: 0.6950 - val_accuracy: 0.4563
# Epoch 5/10
# 80/80 [==============================] - 2s 24ms/step - loss: 0.7055 - accuracy: 0.5102 - val_loss: 0.6943 - val_accuracy: 0.4563
# Epoch 6/10
# 80/80 [==============================] - 2s 28ms/step - loss: 0.6943 - accuracy: 0.5094 - val_loss: 0.6949 - val_accuracy: 0.4563
# Epoch 7/10
# 80/80 [==============================] - 3s 34ms/step - loss: 0.6969 - accuracy: 0.5063 - val_loss: 0.6952 - val_accuracy: 0.4563
# Epoch 8/10
# 80/80 [==============================] - 2s 22ms/step - loss: 0.6964 - accuracy: 0.5086 - val_loss: 0.6947 - val_accuracy: 0.4563
# Epoch 9/10
# 80/80 [==============================] - 2s 22ms/step - loss: 0.6960 - accuracy: 0.5109 - val_loss: 0.6951 - val_accuracy: 0.4563
# Epoch 10/10
# 80/80 [==============================] - 2s 23ms/step - loss: 0.6932 - accuracy: 0.5141 - val_loss: 0.6951 - val_accuracy: 0.4563
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6934 - accuracy: 0.4975
# Test accuracy: 0.4975000023841858
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_41 (Dense)            (None, 5000)              1005000
#
#  dropout_21 (Dropout)        (None, 5000)              0
#
#  dense_42 (Dense)            (None, 128)               640128
#
#  dropout_22 (Dropout)        (None, 128)               0
#
#  dense_43 (Dense)            (None, 64)                8256
#
#  dense_44 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 1653449 (6.31 MB)
# Trainable params: 1653449 (6.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 13/13 [==============================] - 0s 7ms/step

# %%
import os
import numpy as np
from sklearn.preprocessing import StandardScaler

# Veri yükleme
test_folder = '/content/KUL/error'
test_data = []

for filename in os.listdir(test_folder):
    data = np.genfromtxt(os.path.join(test_folder, filename), delimiter=',')
    test_data.append(data)

test_data = np.array(test_data)

# Verileri düzenleme ve normalleştirme
num_samples = len(test_data)
sequence_length = test_data.shape[1]
num_features = test_data.shape[2]
test_data_normalized = test_data.reshape(num_samples, sequence_length * num_features)

# Model ile tahmin yapma
predictions = model.predict(test_data_normalized)

# Tahmin sonuçlarını ekrana yazdırma
for i, prediction in enumerate(predictions):
    print(f'Test Örneği {i+1}: Tahmin Olasılığı = {prediction[0]:.4f}')

# Eğer sınıflandırma yapmak istiyorsanız:
threshold = 0.5
predictions_binary = (predictions > threshold).astype(int)

# Her bir test örneği için tahmin edilen sınıfı yazdırma
for i, prediction in enumerate(predictions_binary):
    print(f'Test Örneği {i+1}: Tahmin Edilen Sınıf = {prediction[0]}')
# Out:
# 1/1 [==============================] - 0s 257ms/step
# Test Örneği 1: Tahmin Olasılığı = 0.0000
# Test Örneği 2: Tahmin Olasılığı = 0.0000
# Test Örneği 1: Tahmin Edilen Sınıf = 0
# Test Örneği 2: Tahmin Edilen Sınıf = 0

# %%
# Modelin performansını değerlendirme
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc}')

# Modelin test seti üzerindeki tahminlerini alınması
y_pred = model.predict(X_test)

# Tahminleri ikili sınıflara dönüştürme (örneğin, eşik değeri 0.5 kullanarak)
threshold = 0.5
y_pred_binary = (y_pred > threshold).astype(int)

# Hatalı tahminlerin sayısını bulma
incorrect_predictions = np.sum(y_pred_binary.flatten() != y_test)

# Toplam test örnek sayısı
total_test_samples = len(y_test)

# Hatalı tahmin oranını hesaplama
error_rate = incorrect_predictions / total_test_samples * 100

print(f'Total test samples: {total_test_samples}')
print(f'Incorrect predictions: {incorrect_predictions}')
print(f'Error rate: {error_rate:.2f}%')
# Out:
# 13/13 [==============================] - 0s 8ms/step - loss: 449.3121 - accuracy: 0.5025
# Test accuracy: 0.5024999976158142
# 13/13 [==============================] - 0s 9ms/step
# Total test samples: 400
# Incorrect predictions: 199
# Error rate: 49.75%

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Model ile tahmin yapma
predictions = model.predict(X_test)

# Tahmin ve gerçek sınıfları içeren bir confusion matrix oluştur
conf_matrix = confusion_matrix(y_test, (predictions > 0.5).astype(int))

# Confusion matrix'i seaborn kütüphanesi ile görselleştirme
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Gerçek 0', 'Gerçek 1'], yticklabels=['Tahmin 0', 'Tahmin 1'])
plt.xlabel('Gerçek Sınıf')
plt.ylabel('Tahmin Edilen Sınıf')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 13/13 [==============================] - 0s 14ms/step
